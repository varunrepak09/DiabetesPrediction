# %%
import tkinter as tk
from tkinter import filedialog
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def Data_analysis():
    file_path = filedialog.askopenfilename(filetypes=[("CSV Files", "*.csv")])
    if file_path:
        data = pd.read_csv(file_path)
        plt.figure()
        sns.histplot(data[' income_annum'])
        plt.title("Histogram for loan approval prediction")
        plt.show()

root = tk.Tk()
root.title("Data Analysis on loan prediction")

upload_button = tk.Button(root, text="select the data file", command=upload_and_analyze)
upload_button.pack(pady=20)

root.mainloop()
